# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.1.0-rc1'

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Using TensorFlow backend.
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
tf.keras.backend.clear_session()
#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

#Reshape data from 2D (28,28) to 3D (28, 28, 1)
model.add(tf.keras.layers.Reshape((28,28,1),input_shape=(28,28,)))

#normalize data
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Add first convolutional layer
model.add(tf.keras.layers.Conv2D(200, #Number of filters 
                                 kernel_size=(3,3), #Size of the filter
                                 activation='relu'))

#Add second convolutional layer
model.add(tf.keras.layers.Conv2D(100, kernel_size=(3,3), activation='relu'))

#Add another dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Flatten the output
model.add(tf.keras.layers.Flatten())

# %%
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 1)         4
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 200)       2000
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 100)       180100
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 100)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 10)                576010
# =================================================================
# Total params: 758,114
# Trainable params: 758,112
# Non-trainable params: 2
# _________________________________________________________________

# %%
#Train the model
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=10,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 830s 14ms/sample - loss: 0.3716 - accuracy: 0.8677 - val_loss: 0.2917 - val_accuracy: 0.8925
# Epoch 2/10
# 60000/60000 [==============================] - 822s 14ms/sample - loss: 0.2471 - accuracy: 0.9107 - val_loss: 0.2680 - val_accuracy: 0.9022
# Epoch 3/10
# 60000/60000 [==============================] - 823s 14ms/sample - loss: 0.1962 - accuracy: 0.9288 - val_loss: 0.2517 - val_accuracy: 0.9104
# Epoch 4/10
# 60000/60000 [==============================] - 824s 14ms/sample - loss: 0.1567 - accuracy: 0.9426 - val_loss: 0.2684 - val_accuracy: 0.9079
# Epoch 5/10
# 60000/60000 [==============================] - 823s 14ms/sample - loss: 0.1311 - accuracy: 0.9518 - val_loss: 0.2599 - val_accuracy: 0.9127
# Epoch 6/10
# 60000/60000 [==============================] - 823s 14ms/sample - loss: 0.1109 - accuracy: 0.9595 - val_loss: 0.2956 - val_accuracy: 0.9116
# Epoch 7/10
# 60000/60000 [==============================] - 824s 14ms/sample - loss: 0.0954 - accuracy: 0.9643 - val_loss: 0.3026 - val_accuracy: 0.9113
# Epoch 8/10
# 60000/60000 [==============================] - 830s 14ms/sample - loss: 0.0819 - accuracy: 0.9695 - val_loss: 0.3274 - val_accuracy: 0.9081
# Epoch 9/10
# 60000/60000 [==============================] - 828s 14ms/sample - loss: 0.0745 - accuracy: 0.9721 - val_loss: 0.3432 - val_accuracy: 0.9129
# Epoch 10/10
# 60000/60000 [==============================] - 827s 14ms/sample - loss: 0.0647 - accuracy: 0.9755 - val_loss: 0.3590 - val_accuracy: 0.9091

# %%
#Testing accuracy after 10 itr is 0.90
